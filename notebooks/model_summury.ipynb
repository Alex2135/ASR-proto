# %%
import sys
sys.path.insert(0,'..')

# %%
from model import EfConfClassifier as Model
from config import *

from torchsummary import summary
from prettytable import PrettyTable

# %%
def count_parameters(model):
    table = PrettyTable(["Modules", "Parameters"])
    total_params = 0
    for name, parameter in model.named_parameters():
        if not parameter.requires_grad: continue
        param = parameter.numel()
        table.add_row([name, param])
        total_params+=param
    print(table)
    print(f"Total Trainable Params: {total_params}")
    return total_params

model = Model(n_encoders=CONFIG["n_encoders"], n_decoders=CONFIG["n_decoders"])
n_params = count_parameters(model)

print(f"Model has {n_params/1e+6:.3f}M params")
# Out:
# +----------------------------------------------------+------------+
# |                      Modules                       | Parameters |
# +----------------------------------------------------+------------+
# |              enc_proc.convs.0.weight               |   344064   |
# |               enc_proc.convs.0.bias                |     64     |
# |               dec_proc.lin.0.weight                |    2432    |
# |                dec_proc.lin.0.bias                 |     64     |
# |           encoder.lacs.0.lffn1.E1.weight           |   16384    |
# |           encoder.lacs.0.lffn1.D1.weight           |   262144   |
# |           encoder.lacs.0.lffn1.E2.weight           |   262144   |
# |           encoder.lacs.0.lffn1.D2.weight           |   16384    |
# |          encoder.lacs.0.mhlsa.W_O.weight           |    4096    |
# |       encoder.lacs.0.conv_module.ln1.weight        |     64     |
# |        encoder.lacs.0.conv_module.ln1.bias         |     64     |
# | encoder.lacs.0.conv_module.pw_conv1.pw_conv.weight |     1      |
# |  encoder.lacs.0.conv_module.pw_conv1.pw_conv.bias  |     1      |
# | encoder.lacs.0.conv_module.dw_conv1d.conv1.weight  |     3      |
# |  encoder.lacs.0.conv_module.dw_conv1d.conv1.bias   |     1      |
# | encoder.lacs.0.conv_module.dw_conv1d.conv2.weight  |     8      |
# |  encoder.lacs.0.conv_module.dw_conv1d.conv2.bias   |     8      |
# |        encoder.lacs.0.conv_module.bn.weight        |     8      |
# |         encoder.lacs.0.conv_module.bn.bias         |     8      |
# | encoder.lacs.0.conv_module.pw_conv2.pw_conv.weight |     8      |
# |  encoder.lacs.0.conv_module.pw_conv2.pw_conv.bias  |     1      |
# |           encoder.lacs.0.lffn2.E1.weight           |   32768    |
# |           encoder.lacs.0.lffn2.D1.weight           |   524288   |
# |           encoder.lacs.0.lffn2.E2.weight           |   524288   |
# |           encoder.lacs.0.lffn2.D2.weight           |   32768    |
# |              encoder.lacs.0.ln.weight              |     64     |
# |               encoder.lacs.0.ln.bias               |     64     |
# |           encoder.lacs.1.lffn1.E1.weight           |   16384    |
# |           encoder.lacs.1.lffn1.D1.weight           |   262144   |
# |           encoder.lacs.1.lffn1.E2.weight           |   262144   |
# |           encoder.lacs.1.lffn1.D2.weight           |   16384    |
# |          encoder.lacs.1.mhlsa.W_O.weight           |    4096    |
# |       encoder.lacs.1.conv_module.ln1.weight        |     64     |
# |        encoder.lacs.1.conv_module.ln1.bias         |     64     |
# | encoder.lacs.1.conv_module.pw_conv1.pw_conv.weight |     1      |
# |  encoder.lacs.1.conv_module.pw_conv1.pw_conv.bias  |     1      |
# | encoder.lacs.1.conv_module.dw_conv1d.conv1.weight  |     3      |
# |  encoder.lacs.1.conv_module.dw_conv1d.conv1.bias   |     1      |
# | encoder.lacs.1.conv_module.dw_conv1d.conv2.weight  |     8      |
# |  encoder.lacs.1.conv_module.dw_conv1d.conv2.bias   |     8      |
# |        encoder.lacs.1.conv_module.bn.weight        |     8      |
# |         encoder.lacs.1.conv_module.bn.bias         |     8      |
# | encoder.lacs.1.conv_module.pw_conv2.pw_conv.weight |     8      |
# |  encoder.lacs.1.conv_module.pw_conv2.pw_conv.bias  |     1      |
# |           encoder.lacs.1.lffn2.E1.weight           |   32768    |
# |           encoder.lacs.1.lffn2.D1.weight           |   524288   |
# |           encoder.lacs.1.lffn2.E2.weight           |   524288   |
# |           encoder.lacs.1.lffn2.D2.weight           |   32768    |
# |              encoder.lacs.1.ln.weight              |     64     |
# |               encoder.lacs.1.ln.bias               |     64     |
# |           encoder.lacs.2.lffn1.E1.weight           |   16384    |
# |           encoder.lacs.2.lffn1.D1.weight           |   262144   |
# |           encoder.lacs.2.lffn1.E2.weight           |   262144   |
# |           encoder.lacs.2.lffn1.D2.weight           |   16384    |
# |          encoder.lacs.2.mhlsa.W_O.weight           |    4096    |
# |       encoder.lacs.2.conv_module.ln1.weight        |     64     |
# |        encoder.lacs.2.conv_module.ln1.bias         |     64     |
# | encoder.lacs.2.conv_module.pw_conv1.pw_conv.weight |     1      |
# |  encoder.lacs.2.conv_module.pw_conv1.pw_conv.bias  |     1      |
# | encoder.lacs.2.conv_module.dw_conv1d.conv1.weight  |     3      |
# |  encoder.lacs.2.conv_module.dw_conv1d.conv1.bias   |     1      |
# | encoder.lacs.2.conv_module.dw_conv1d.conv2.weight  |     8      |
# |  encoder.lacs.2.conv_module.dw_conv1d.conv2.bias   |     8      |
# |        encoder.lacs.2.conv_module.bn.weight        |     8      |
# |         encoder.lacs.2.conv_module.bn.bias         |     8      |
# | encoder.lacs.2.conv_module.pw_conv2.pw_conv.weight |     8      |
# |  encoder.lacs.2.conv_module.pw_conv2.pw_conv.bias  |     1      |
# |           encoder.lacs.2.lffn2.E1.weight           |   32768    |
# |           encoder.lacs.2.lffn2.D1.weight           |   524288   |
# |           encoder.lacs.2.lffn2.E2.weight           |   524288   |
# |           encoder.lacs.2.lffn2.D2.weight           |   32768    |
# |              encoder.lacs.2.ln.weight              |     64     |
# |               encoder.lacs.2.ln.bias               |     64     |
# |   decoder.dec_blocks.0.mhla_with_mask.W_O.weight   |    4096    |
# |          decoder.dec_blocks.0.ln1.weight           |     64     |
# |           decoder.dec_blocks.0.ln1.bias            |     64     |
# |  decoder.dec_blocks.0.mhla_with_memory.W_O.weight  |    4096    |
# |          decoder.dec_blocks.0.ln2.weight           |     64     |
# |           decoder.dec_blocks.0.ln2.bias            |     64     |
# |        decoder.dec_blocks.0.lffn.E1.weight         |   32768    |
# |        decoder.dec_blocks.0.lffn.D1.weight         |   524288   |
# |        decoder.dec_blocks.0.lffn.E2.weight         |   524288   |
# |        decoder.dec_blocks.0.lffn.D2.weight         |   32768    |
# |          decoder.dec_blocks.0.ln3.weight           |     64     |
# |           decoder.dec_blocks.0.ln3.bias            |     64     |
# |                  lin_out.0.weight                  |    320     |
# |                   lin_out.0.bias                   |     5      |
# +----------------------------------------------------+------------+
# Total Trainable Params: 6496338
# Model has 6.496M params
